# %%
import gene_prediction as gp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-9ec31d6b8c63> in <module>
# ----> 1 import gene_prediction as gp
#
# ModuleNotFoundError: No module named 'gene_prediction'

# %%
x_test
# Out:
#         GeneId  H3K4me3  H3K4me1  H3K36me3  H3K9me3  H3K27me3
# 0            1        2        3         4        3         4
# 1            1        0        0         4        3         2
# 2            1        2        1         4        1         1
# 3            1        1        0         2        0         6
# 4            1        1        0         3        0         5
# 5            1        0        3         1        0         3
# 6            1        1        1         5        0         1
# 7            1        1        2         7        2         2
# 8            1        1        0         7        4         3
# 9            1        0        0         3        0         3
# 10           1        0        0         0        0         0
# 11           1        0        1         1        0         0
# 12           1        1        2         5        2         2
# 13           1        2        0         7        1         3
# ...
